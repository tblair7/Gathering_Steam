# %%
import steam_reviews
import pandas as pd
import pickle as pckl

# %%
reviews_MHW = steam_reviews.get('774861')
#game_name = 'no_mans_sky' Monster Hunter World
# Out:
# 16 reviews found...
# 17 reviews found...
# Found all reviews.

# %%
#pckl.dump(reviews_MHW,open('monster_hunter_world.pckl', 'wb'))

# %%
reviews_MHW
# Out:
# [{'recommendationid': '48840863',
#   'author': {'steamid': '76561198024998310',
#    'num_games_owned': 167,
#    'num_reviews': 1,
#    'playtime_forever': 334,
#    'playtime_last_two_weeks': 334,
#    'last_played': 1549612111},
#   'language': 'english',
# ...

# %%
df_norm = pd.io.json.json_normalize(reviews)

# %%
df_norm.head()
# Out:
#    author.last_played  author.num_games_owned  author.num_reviews  \
# 0          1548014842                       6                   1
# 1          1548017764                     238                  35
# 2          1545131771                     171                   3
# 3          1504742084                     377                   6
# 4          1548017463                      11                   1
#
#    author.playtime_forever  author.playtime_last_two_weeks     author.steamid  \
# 0                      412                             412  76561198846762449
# 1                     2235                            2235  76561198008955625
# 2                     5473                               0  76561197991488912
# 3                      101                               0  76561198013957136
# 4                      575                             575  76561197993720855
#
#    comment_count language  received_for_free recommendationid  \
# ...

# %%
pckl.dump(df_norm,open('{0}.pckl'.format(game_name),'wb'))

# %%
a = df_norm.sort_values(by='author.playtime_forever',ascending = False)

# %%
a.head()
# Out:
#        author.last_played  author.num_games_owned  author.num_reviews  \
# 78411          1547007602                      15                   1
# 79404          1547760500                      17                   1
# 37147          1546672306                      21                   1
# 84428          1547047474                      24                   1
# 84432          1547047474                      24                   1
#
#        author.playtime_forever  author.playtime_last_two_weeks  \
# 78411                  1084573                               1
# 79404                  1079459                            1995
# 37147                   988994                               0
# 84428                   980780                            1854
# 84432                   980780                            1854
#
#           author.steamid  comment_count language  received_for_free  \
# 78411  76561198118134364              0  english              False
# ...

# %%
df_norm.loc[df_norm['review'] == "Really wish the devs would just optimize the game and fix the overwhelming amount of bugs instead of forcefeeding the community new DLC's"]
# Out:
#       author.last_played  author.num_games_owned  author.num_reviews  \
# 1036          1546094968                     101                   2
#
#       author.playtime_forever  author.playtime_last_two_weeks  \
# 1036                     8926                               0
#
#          author.steamid  comment_count language  received_for_free  \
# 1036  76561198100205219              0  english              False
#
#      recommendationid                                             review  \
# 1036         47913501  Really wish the devs would just optimize the g...
#
#       steam_purchase  timestamp_created  timestamp_updated  voted_up  \
# 1036            True         1546051835         1546051835     False
#
#       votes_funny  votes_up   weighted_vote_score  written_during_early_access
# 1036            9       164  0.818648099899291992                        False

# %%
len(reviews)
# Out:
# 107106

# %%
import wtforms
